# %% [markdown]
# ##Assignment 3
#
# 1.Download the data set /content/Flowers-Dataset.zip
#
# importing libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# #DataSet Augmentation
#
# 1.dataset consists of 5 different flowers
# 2.daisy
# 3.dandelion
# 4.rose
# 5.sunflower
# 6.tulip

# %% [markdown]
# #Unzip the dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/Flowers-Dataset.zip

# %%
folder = 'flowers/'

# %%
train_data = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data.flow_from_directory(folder,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data.flow_from_directory(folder,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3024 images belonging to 5 classes.
# Found 1293 images belonging to 5 classes.

# %% [markdown]
# #Model Build Using CNN
#
# 1.Create the model

# %%
Cnn_model = Sequential()

#convolution layer and Pooling layer 1
Cnn_model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
Cnn_model.add(MaxPool2D(pool_size=2,strides=2))
Cnn_model.add(Dropout(0.4))

#convolution layer and Pooling layer 2
Cnn_model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
Cnn_model.add(MaxPool2D(pool_size=2,strides=2))
Cnn_model.add(Dropout(0.4))

#Flattening the images
Cnn_model.add(Flatten())

#Fully Connected layers
Cnn_model.add(Dense(64,activation='relu'))
Cnn_model.add(Dropout(0.4))
Cnn_model.add(Dense(5,activation='softmax'))

# %%
Cnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 62, 62, 48)        1344
#
#  max_pooling2d_4 (MaxPooling  (None, 31, 31, 48)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 31, 31, 48)        0
#
#  conv2d_5 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_4 (Dense)             (None, 64)                401472
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# ...
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 2.Compile the model

# %%
Cnn_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# 3.

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# 4.Training the models

# %%
Result = Cnn_model.fit(x=training_set, validation_data=testing_set, epochs=40)
# Out:
# Epoch 1/40
# 31/31 [==============================] - 33s 1s/step - loss: 0.9899 - accuracy: 0.6088 - val_loss: 1.0125 - val_accuracy: 0.6009
# Epoch 2/40
# 31/31 [==============================] - 32s 1s/step - loss: 0.9779 - accuracy: 0.6197 - val_loss: 0.9968 - val_accuracy: 0.6203
# Epoch 3/40
# 31/31 [==============================] - 40s 1s/step - loss: 0.9759 - accuracy: 0.6200 - val_loss: 1.0421 - val_accuracy: 0.6009
# Epoch 4/40
# 31/31 [==============================] - 40s 1s/step - loss: 0.9698 - accuracy: 0.6095 - val_loss: 1.0045 - val_accuracy: 0.6094
# Epoch 5/40
# 31/31 [==============================] - 37s 1s/step - loss: 0.9501 - accuracy: 0.6250 - val_loss: 1.0402 - val_accuracy: 0.6071
# Epoch 6/40
# 31/31 [==============================] - 33s 1s/step - loss: 0.9265 - accuracy: 0.6346 - val_loss: 0.9266 - val_accuracy: 0.6442
# Epoch 7/40
# ...

# %% [markdown]
# 5.Plot loss and accuracy

# %%
#Loss
plt.plot(Result.history['loss'], label='train loss')
plt.plot(Result.history['val_loss'], label='value loss')
plt.legend()
plt.show()

#Accuracy
plt.plot(Result.history['accuracy'], label='train accuracy')
plt.plot(Result.history['val_accuracy'], label='value accuracy')
plt.legend()
plt.show()

# %% [markdown]
# 6.Save the model

# %%
Cnn_model.save('flower.h5')

# %% [markdown]
# #Test The Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#Sample1
img_show('/content/flowers/daisy/20580471306_ab5a011b15_n.jpg')
testing('/content/flowers/daisy/20580471306_ab5a011b15_n.jpg')
# Out:
# Predicted class as: Daisy

# %%
#Sample2
img_show('/content/flowers/dandelion/3372748508_e5a4eacfcb_n.jpg')
testing('/content/flowers/dandelion/3372748508_e5a4eacfcb_n.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#Sample3
img_show('/content/flowers/rose/15236835789_6009b8f33d.jpg')
testing('/content/flowers/rose/15236835789_6009b8f33d.jpg')
# Out:
# Predicted class as: Tulip

# %%
#Sample4
img_show('/content/flowers/sunflower/9231555352_d2dd8f8e68_m.jpg')
testing('/content/flowers/sunflower/9231555352_d2dd8f8e68_m.jpg')
# Out:
# Predicted class as: Tulip

# %%
#Sample5
img_show('/content/flowers/tulip/8555123165_2fe57eff4f.jpg')
testing('/content/flowers/tulip/8555123165_2fe57eff4f.jpg')
# Out:
# Predicted class as: Tulip

# %% [markdown]
# In this Assignment,
#  1.I have find how many classes in the dataset.
#  2.Then create cnn layers
#  3.Two cnn layers consists 1344 parameters.
#  4.Testing model gives an 95% accuracy.
