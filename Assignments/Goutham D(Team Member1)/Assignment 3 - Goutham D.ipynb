# %% [markdown]
# 1.unzip dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/Flowers-Dataset.zip

# %% [markdown]
# Importing the libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# 2.Image Augumentation

# %%
path = 'flowers/'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3024 images belonging to 5 classes.
# Found 1293 images belonging to 5 classes.

# %% [markdown]
# 3.Creating the Model

# %%
model = Sequential()

# %% [markdown]
# 4.Adding the Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 5.Compiling the Model

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# 6.Fit the Model

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# Training the Model

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 31s 948ms/step - loss: 1.5511 - accuracy: 0.2937 - val_loss: 1.4298 - val_accuracy: 0.3991
# Epoch 2/50
# 31/31 [==============================] - 29s 936ms/step - loss: 1.3159 - accuracy: 0.4266 - val_loss: 1.2463 - val_accuracy: 0.4934
# Epoch 3/50
# 31/31 [==============================] - 29s 936ms/step - loss: 1.1985 - accuracy: 0.5053 - val_loss: 1.1711 - val_accuracy: 0.5321
# Epoch 4/50
# 31/31 [==============================] - 29s 938ms/step - loss: 1.1472 - accuracy: 0.5364 - val_loss: 1.1563 - val_accuracy: 0.5089
# Epoch 5/50
# 31/31 [==============================] - 29s 936ms/step - loss: 1.0841 - accuracy: 0.5645 - val_loss: 1.0935 - val_accuracy: 0.5646
# Epoch 6/50
# 31/31 [==============================] - 29s 928ms/step - loss: 1.0496 - accuracy: 0.5784 - val_loss: 1.0961 - val_accuracy: 0.5507
# Epoch 7/50
# 31/31 [==============================] - 29s 940ms/step - loss: 0.9906 - accuracy: 0.6032 - val_loss: 1.0982 - val_accuracy: 0.5646
# Epoch 8/50
# 31/31 [==============================] - 29s 940ms/step - loss: 0.9580 - accuracy: 0.6220 - val_loss: 1.1227 - val_accuracy: 0.5561
# Epoch 9/50
# 31/31 [==============================] - 29s 938ms/step - loss: 0.9178 - accuracy: 0.6346 - val_loss: 1.0312 - val_accuracy: 0.6032
# Epoch 10/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.9355 - accuracy: 0.6323 - val_loss: 1.0588 - val_accuracy: 0.5847
# Epoch 11/50
# 31/31 [==============================] - 29s 936ms/step - loss: 0.8751 - accuracy: 0.6604 - val_loss: 1.0587 - val_accuracy: 0.5994
# Epoch 12/50
# 31/31 [==============================] - 29s 938ms/step - loss: 0.8811 - accuracy: 0.6601 - val_loss: 1.0187 - val_accuracy: 0.6071
# Epoch 13/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.8634 - accuracy: 0.6630 - val_loss: 1.0004 - val_accuracy: 0.6241
# Epoch 14/50
# 31/31 [==============================] - 29s 938ms/step - loss: 0.8424 - accuracy: 0.6792 - val_loss: 1.0124 - val_accuracy: 0.6203
# Epoch 15/50
# 31/31 [==============================] - 29s 938ms/step - loss: 0.8381 - accuracy: 0.6726 - val_loss: 0.9321 - val_accuracy: 0.6527
# Epoch 16/50
# 31/31 [==============================] - 29s 936ms/step - loss: 0.8068 - accuracy: 0.6925 - val_loss: 0.9241 - val_accuracy: 0.6481
# Epoch 17/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.7883 - accuracy: 0.7004 - val_loss: 0.9801 - val_accuracy: 0.6272
# Epoch 18/50
# 31/31 [==============================] - 29s 932ms/step - loss: 0.7771 - accuracy: 0.7001 - val_loss: 1.0250 - val_accuracy: 0.6288
# Epoch 19/50
# 31/31 [==============================] - 29s 937ms/step - loss: 0.7540 - accuracy: 0.7136 - val_loss: 0.9031 - val_accuracy: 0.6504
# Epoch 20/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.7510 - accuracy: 0.7027 - val_loss: 0.9118 - val_accuracy: 0.6551
# Epoch 21/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.7399 - accuracy: 0.7057 - val_loss: 1.0045 - val_accuracy: 0.6265
# Epoch 22/50
# 31/31 [==============================] - 29s 936ms/step - loss: 0.7019 - accuracy: 0.7302 - val_loss: 0.9510 - val_accuracy: 0.6504
# Epoch 23/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.7096 - accuracy: 0.7272 - val_loss: 0.9453 - val_accuracy: 0.6628
# Epoch 24/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.7110 - accuracy: 0.7292 - val_loss: 0.9054 - val_accuracy: 0.6489
# Epoch 25/50
# 31/31 [==============================] - 29s 934ms/step - loss: 0.7051 - accuracy: 0.7427 - val_loss: 0.9696 - val_accuracy: 0.6628
# Epoch 26/50
# 31/31 [==============================] - 29s 932ms/step - loss: 0.7071 - accuracy: 0.7318 - val_loss: 0.9849 - val_accuracy: 0.6427
# Epoch 27/50
# 31/31 [==============================] - 29s 932ms/step - loss: 0.6587 - accuracy: 0.7454 - val_loss: 0.9229 - val_accuracy: 0.6497
# Epoch 28/50
# 31/31 [==============================] - 29s 936ms/step - loss: 0.6562 - accuracy: 0.7427 - val_loss: 1.1921 - val_accuracy: 0.6056
# Epoch 29/50
# 31/31 [==============================] - 29s 934ms/step - loss: 0.6860 - accuracy: 0.7331 - val_loss: 0.9909 - val_accuracy: 0.6489
# Epoch 30/50
# 31/31 [==============================] - 29s 931ms/step - loss: 0.6568 - accuracy: 0.7457 - val_loss: 0.9347 - val_accuracy: 0.6674
# Epoch 31/50
# 31/31 [==============================] - 29s 931ms/step - loss: 0.6355 - accuracy: 0.7560 - val_loss: 0.9508 - val_accuracy: 0.6628
# Epoch 32/50
# 31/31 [==============================] - 29s 934ms/step - loss: 0.6120 - accuracy: 0.7596 - val_loss: 0.9237 - val_accuracy: 0.6759
# Epoch 33/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.6248 - accuracy: 0.7599 - val_loss: 0.9632 - val_accuracy: 0.6489
# Epoch 34/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.5933 - accuracy: 0.7741 - val_loss: 0.9406 - val_accuracy: 0.6713
# Epoch 35/50
# 31/31 [==============================] - 29s 936ms/step - loss: 0.5788 - accuracy: 0.7722 - val_loss: 1.0016 - val_accuracy: 0.6705
# Epoch 36/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.5692 - accuracy: 0.7801 - val_loss: 0.9239 - val_accuracy: 0.6698
# Epoch 37/50
# 31/31 [==============================] - 29s 928ms/step - loss: 0.5989 - accuracy: 0.7748 - val_loss: 0.9797 - val_accuracy: 0.6589
# Epoch 38/50
# 31/31 [==============================] - 29s 931ms/step - loss: 0.5650 - accuracy: 0.7751 - val_loss: 0.9002 - val_accuracy: 0.6783
# Epoch 39/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.5500 - accuracy: 0.7920 - val_loss: 0.9451 - val_accuracy: 0.6721
# Epoch 40/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.5545 - accuracy: 0.7847 - val_loss: 0.9242 - val_accuracy: 0.6690
# Epoch 41/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.5604 - accuracy: 0.7854 - val_loss: 1.0037 - val_accuracy: 0.6566
# Epoch 42/50
# 31/31 [==============================] - 29s 933ms/step - loss: 0.5318 - accuracy: 0.7867 - val_loss: 0.9655 - val_accuracy: 0.6829
# Epoch 43/50
# 31/31 [==============================] - 29s 931ms/step - loss: 0.5143 - accuracy: 0.7966 - val_loss: 0.8938 - val_accuracy: 0.6845
# Epoch 44/50
# 31/31 [==============================] - 29s 932ms/step - loss: 0.5338 - accuracy: 0.7900 - val_loss: 0.9992 - val_accuracy: 0.6744
# Epoch 45/50
# 31/31 [==============================] - 29s 934ms/step - loss: 0.5047 - accuracy: 0.8052 - val_loss: 1.0494 - val_accuracy: 0.6636
# Epoch 46/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.4980 - accuracy: 0.8069 - val_loss: 0.9808 - val_accuracy: 0.6783
# Epoch 47/50
# 31/31 [==============================] - 29s 934ms/step - loss: 0.4920 - accuracy: 0.8155 - val_loss: 0.9584 - val_accuracy: 0.6759
# Epoch 48/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.5046 - accuracy: 0.8085 - val_loss: 0.9136 - val_accuracy: 0.6814
# Epoch 49/50
# 31/31 [==============================] - 29s 935ms/step - loss: 0.4949 - accuracy: 0.8089 - val_loss: 0.9673 - val_accuracy: 0.6767
# Epoch 50/50
# 31/31 [==============================] - 29s 940ms/step - loss: 0.4913 - accuracy: 0.8069 - val_loss: 0.9170 - val_accuracy: 0.6914

# %% [markdown]
# Checking Loss and Accuracy using Plot

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# 7.Save the Model

# %%
model.save('flower.h5')

# %% [markdown]
# 8.Testing the Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/flowers/daisy/5632774792_0fa33d17eb_n.jpg')
testing('/content/flowers/daisy/5632774792_0fa33d17eb_n.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test2
img_show('/content/flowers/dandelion/18276105805_d31d3f7e71.jpg')
testing('/content/flowers/dandelion/18276105805_d31d3f7e71.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test3
img_show('/content/flowers/rose/22506717337_0fd63e53e9.jpg')
testing('/content/flowers/rose/22506717337_0fd63e53e9.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test4
img_show('/content/flowers/sunflower/23645265812_24352ff6bf.jpg')
testing('/content/flowers/sunflower/23645265812_24352ff6bf.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test5
img_show('/content/flowers/tulip/3510294699_bc4c72cb7d_n.jpg')
testing('/content/flowers/tulip/3510294699_bc4c72cb7d_n.jpg')
# Out:
# Predicted class as: Tulip
